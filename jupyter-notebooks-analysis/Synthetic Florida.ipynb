# %%
df = read.csv("data/cdc_homicide_firearm.csv")
df
# Out:
#      State     State.Code Year Year.Code Month      Month.Code Deaths
# 1    Alabama   1          1999 1999      Jan., 1999 1999/01    27
# 2    Alabama   1          1999 1999      Feb., 1999 1999/02    24
# 3    Alabama   1          1999 1999      Mar., 1999 1999/03    21
# 4    Alabama   1          1999 1999      Apr., 1999 1999/04    17
# 5    Alabama   1          1999 1999      May, 1999  1999/05    26
# 6    Alabama   1          1999 1999      Jun., 1999 1999/06    25
# 7    Alabama   1          1999 1999      Jul., 1999 1999/07    25
# 8    Alabama   1          1999 1999      Aug., 1999 1999/08    29
# 9    Alabama   1          1999 1999      Sep., 1999 1999/09    27
# 10   Alabama   1          1999 1999      Oct., 1999 1999/10    20
# 11   Alabama   1          1999 1999      Nov., 1999 1999/11    21
# 12   Alabama   1          1999 1999      Dec., 1999 1999/12    31
# 13   Alabama   1          2000 2000      Jan., 2000 2000/01    24
# ...
